# %% [markdown]
# # Category Classification
# Model which classifies our events.
#
# ### TODO
# - Define how we want to classify our events (categories, sub-categories)

# %%
# import modules
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data
# Below we see the composition of our data

# %%
# load data
events = pd.read_json('data/events_training_data_v2.json')
events
# Out:
#           city                                             detail  \
# 0    Vancouver   Awe-inspiring dance, extraordinary theatre, h...
# 1    Vancouver   Our part-time 200 Hour Yoga Teacher Training ...
# 2    Vancouver   Representing one of the most important donati...
# 3    Vancouver   The electrifying play that became the legenda...
# 4    Vancouver   Watch 'Amazon Adventure: A True Story of Scie...
# 5    Vancouver   Celebrating the excessive abundance of the ar...
# 6    Vancouver   Level 1\nDates: Tuesdays, Jan 9 - Apr 17\nTim...
# 7    Vancouver   Big Top has returned to their famed weekly re...
# 8    Vancouver   We're back! The Birth Fair brings together pr...
# 9    Vancouver   BOMBHEAD is a thematic exhibition organized b...
# 10   Vancouver   A thrilling look at the lives of two teenage ...
# 11   Vancouver   Members of The Society of Children’s Book Wri...
# 12   Vancouver   New Media Gallery opens the year with an enig...
# 13   Vancouver   EVERY OTHER WEEKEND Starting January 26-28!\n...
# 14   Vancouver   Opening Reception on Friday, March 2, 3 - 6pm...
# 15   Vancouver   Evolve Your Craft - Focused on adults seeking...
# 16   Vancouver   In the winter of 2015 Nicola Tibbetts became ...
# 17   Vancouver   FESTIVAL Nanaimo is a multi-dimensional commu...
# 18   Vancouver   A NEW PLAY ABOUT MOVING FORWARD\nby Jill Daum...
# 19   Vancouver   Our Full-Time Spa Therapy program is designed...
# 20   Vancouver   THE COMING-OF-AGE MUSICAL\n\nAlison’s father ...
# 21   Vancouver   Join our weekly hands-on show-and-tell / open...
# 22   Vancouver   Join us for Haunted History Walking Tours thr...
# 23   Vancouver   Shop for farm-to-table goodness each Sunday f...
# 24   Vancouver   Just Yoga's 200HR YIN + YANG Teacher Training...
# 25   Vancouver   exhibition presents more than 110 historical ...
# 26   Vancouver   The Vancouver Maritime Museum proudly announc...
# 27   Vancouver   Join music, dance and shadow puppet master Su...
# 28   Vancouver   Opening Reception: Saturday, March 3, 2:00 - ...
# 29   Vancouver   JFL NorthWest, Vancouver’s comedy festival, r...
# ..         ...                                                ...
# 486  Vancouver   The Rickshaw presents Bison's 'Earthbound' 11...
# 487  Vancouver   One of the brightest lights in New York’s jaz...
# 488  Vancouver   English indie-pop band tours in support of up...
# 489  Vancouver   Russian composer Sergei Rachmaninov’s music f...
# 490  Vancouver   The ANZA Club is thrilled to present The Whee...
# 491  Vancouver   Every night join us on Granville Island at Th...
# 492  Vancouver   Black Suit Devil is an Acoustic Soul project ...
# 493  Vancouver   What is Rent Cheque?! It's an amateur $trip n...
# 494  Vancouver   ANTIQUE & COLLECTABLE SHOW\n\nAGRIPLEX - Clov...
# 495  Vancouver   Join us for the 3rd annual Big Bunny Run on M...
# 496  Vancouver   Bunnies, eggs and other tasty treats for spri...
# 497  Vancouver   The Vancouver Canucks take on the Columbus Bl...
# 498  Vancouver   arshmallow bunnies and lambs, coconut chicks ...
# 499  Vancouver   Canadian alt-rock band coheadlines with Canad...
# 500  Vancouver   Elite Canadian Championship Wrestling celebra...
# 501  Vancouver   American folk musician performs on her Fine B...
# 502  Vancouver   B.C. folk-rock band tours in support of upcom...
# 503  Vancouver   U.K. rock band tours in support of upcoming r...
# 504  Vancouver   Join us this Easter Sunday & spend a unique &...
# 505  Vancouver   MRG Concerts presents Protest the Hero's 'For...
# 506  Vancouver   English indie-rock singer-songwriter tours in...
# 507  Vancouver   Berlin-based modern classical-electronica com...
# 508  Vancouver   MRG Concerts presents LA hardcore punk band T...
# 509  Vancouver   Calling all Voices!\nThe Vancouver Cherry Blo...
# 510  Vancouver   The Vancouver Canucks take on the Vegas Golde...
# 511  Vancouver   This course is our foundational offering, whi...
# 512  Vancouver               London-based modern soul collective.
# 513  Vancouver   Canadian indie-pop band tours in support of l...
# 514  Vancouver   English indie-pop singer-songwriter tours in ...
# 515  Vancouver   British rock 'n' roll band performs on its Sp...
#
#                                                   name  \
# 0                        18th Annual Chutzpah Festival
# 1             200 Hour Yoga Teacher Training Vancouver
# 2        A Cultivating Journey: The Herman Levy Legacy
# 3                                       A Few Good Men
# 4                        Amazon Adventure in IMAX film
# 5        Beginning with the Seventies: GLUT exhibition
# 6                         Bellydance Classes with Maki
# 7                                      BigTop Tuesdays
# 8                                           Birth Fair
# 9                                             Bombhead
# 10                                               Boost
# 11                 Canada West Illustrators Group Show
# 12                                              Corpus
# 13                   Eastside Flea Spring Markets 2018
# 14             Ebb and Flow- Works by Tony Yin Tak Chu
# 15   Entry-Level Industry Workshop Series- 3D Anima...
# 16                    Featured Artist: Nicola Tibbetts
# 17                                    Festival Nanaimo
# 18                               Forget About Tomorrow
# 19                      Full-Time Spa Therapy Program
# 20                                            Fun Home
# 21   Get to Know Rare Books and Special Collections...
# 22                             Ghostly Vancouver Tours
# 23                 Hastings Park Winter Farmers Market
# 24       Hatha + Yin Yoga 200HR Yoga Teacher Training
# 25   In a Different Light: Reflecting on Northwest ...
# 26                                     Into the Arctic
# 27                           Intro to Javanese Gamelan
# 28                      Jamie Evrard: Brief Splendours
# 29                                      JFL NorthWest
# ..                                                 ...
# 486                Bison 'Earthbound' 11th Anniversary
# 487              From New York: Spike Wilner Quartet.
# 488                                         Pale Waves
# 489     Rachmaninov Vespers and Lauridsen Lux aeterna
# 490               The Wheelgrinders and The Neon Stars
# 491                                              Vinyl
# 492                                   Black Suit Devil
# 493                                        Rent Cheque
# 494              Cloverdale Antique & Collectible Show
# 495                         Big Bunny Run and Egg Hunt
# 496                            Easter Chocolate Making
# 497                           Canucks vs. Blue Jackets
# 498                                    Easter Cupcakes
# 499                    Our Lady Peace and Matthew Good
# 500                         ECCW 22nd Anniversary Live
# 501                                          Liza Anne
# 502                                        Shred Kelly
# 503                                       The Go! Team
# 504                                  Easter Bunny Yoga
# 505                                   Protest the Hero
# 506                                          Jake Bugg
# 507                                         Nils Frahm
# 508                                          The Bronx
# 509                           Vancouver Sings One Song
# 510                         Canucks vs. Golden Knights
# 511    Jelly Academy Professional Certification Course
# 512                                             Jungle
# 513                                            Alvvays
# 514                                          Kate Nash
# 515                                        The Strypes
#
#                           source-tags            time  time_provided  \
# 0        [Festivals, Performing Arts]             NaN          False
# 1                             [Other]      7:30-10 pm           True
# 2                         [Galleries]             NaN          False
# 3                           [Theatre]            8 pm           True
# 4                 [Film, Kids' Stuff]             NaN          False
# 5               [Galleries, Activism]             NaN          False
# 6            [Dance, Performing Arts]             NaN          False
# 7     [Performing Arts, Food & Drink]      8:30-11 pm           True
# 8                             [Other]      10 am–3 pm           True
# 9                         [Galleries]             NaN          False
# 10                             [Film]             NaN          False
# 11        [Galleries, Literary/Books]             NaN          False
# 12       [Galleries, Performing Arts]             NaN          False
# 13                          [Markets]             NaN          False
# 14                        [Galleries]             NaN          False
# 15                            [Other]             NaN          False
# 16               [Galleries, Museums]             NaN          False
# 17                        [Festivals]             NaN          False
# 18                          [Theatre]             NaN          False
# 19                            [Other]             NaN          False
# 20                          [Theatre]             NaN          False
# 21                   [Literary/Books]     11 am–12 pm           True
# 22           [Attractions, Nightlife]             NaN          False
# 23            [Markets, Food & Drink]      10 am–2 pm           True
# 24                    [Other, Sports]          5-4 pm           True
# 25                          [Museums]             NaN          False
# 26               [Museums, Galleries]      10 am–5 pm           True
# 27           [Performing Arts, Other]       6-7:30 pm           True
# 28                        [Galleries]             NaN          False
# 29                [Comedy, Festivals]             NaN          False
# ..                                ...             ...            ...
# 486             [Concerts, Nightlife]            8 pm           True
# 487                        [Concerts]            8 pm           True
# 488                        [Concerts]       show 8 pm           True
# 489                        [Concerts]         8-10 pm           True
# 490                        [Concerts]            8 pm           True
# 491          [Concerts, Food & Drink]         8:30 pm           True
# 492      [Performing Arts, Nightlife]            9 pm           True
# 493      [Performing Arts, Nightlife]            9 pm           True
# 494                         [Markets]       9 am–3 pm           True
# 495                 [Holiday, Sports]   11:30 am–4 pm           True
# 496            [Kids' Stuff, Museums]         12-1 pm           True
# 497                          [Sports]            1 pm           True
# 498            [Kids' Stuff, Museums]       1:30-3 pm           True
# 499                        [Concerts]       show 7 pm           True
# 500                          [Sports]            8 pm           True
# 501                        [Concerts]       show 8 pm           True
# 502                        [Concerts]       show 8 pm           True
# 503                        [Concerts]       show 8 pm           True
# 504  [Fundraisers & Charity, Holiday]          2-3 pm           True
# 505             [Concerts, Nightlife]            8 pm           True
# 506                        [Concerts]       show 9 pm           True
# 507                        [Concerts]       show 9 pm           True
# 508             [Concerts, Nightlife]            7 pm           True
# 509             [Festivals, Concerts]    6:30-9:30 pm           True
# 510                          [Sports]            7 pm           True
# 511                           [Other]         7-10 pm           True
# 512                        [Concerts]       show 9 pm           True
# 513                        [Concerts]       show 9 pm           True
# 514                        [Concerts]       show 9 pm           True
# 515                        [Concerts]       show 9 pm           True
#
#                                                  venue
# 0                             Norman Rothstein Theatre
# 1                                      Semperviva Yoga
# 2                                Vancouver Art Gallery
# 3                               Deep Cove Shaw Theatre
# 4              Science World at Telus World of Science
# 5                  Morris and Helen Belkin Art Gallery
# 6                              Scotiabank Dance Centre
# 7                                           Libra Room
# 8                                  Cloverdale Agriplex
# 9                                Vancouver Art Gallery
# 10                        SilverCity Riverport Cinemas
# 11                          Lynn Valley Library Square
# 12                                   New Media Gallery
# 13                                  The Ellis Building
# 14                                          Art Beatus
# 15               VFS Animation & Visual Effects Campus
# 16   Art Rental and Sales at the Vancouver Art Gallery
# 17                                    The Port Theatre
# 18            Goldcorp Stage at the BMO Theatre Centre
# 19            Vancouver School of Bodywork and Massage
# 20                              Granville Island Stage
# 21                    Irving K. Barber Learning Centre
# 22                                             Gastown
# 23                                                 PNE
# 24                                 Just Yoga Vancouver
# 25                   The Museum of Anthropology at UBC
# 26                           Vancouver Maritime Museum
# 27                                       Western Front
# 28                                      Bau-Xi Gallery
# 29                            various Vancouver venues
# ..                                                 ...
# 486                                   Rickshaw Theatre
# 487                                Frankie’s Jazz Club
# 488                                   Biltmore Cabaret
# 489                                    Orpheum Theatre
# 490                                      The ANZA Club
# 491                         Sandbar Seafood Restaurant
# 492                                      The Yard Cafe
# 493                                        Astoria Pub
# 494                    Cloverdale Fairgrounds Agriplex
# 495                                 Jericho Beach Park
# 496                Mackin Heritage Home and Toy Museum
# 497                                       Rogers Arena
# 498                Mackin Heritage Home and Toy Museum
# 499                                  Abbotsford Centre
# 500               Molson Canadian Theatre at Hard Rock
# 501                                   Biltmore Cabaret
# 502                                             Cobalt
# 503                                        Fox Cabaret
# 504                                   Sunberry Fitness
# 505                                   Rickshaw Theatre
# 506                                 Commodore Ballroom
# 507                                      Vogue Theatre
# 508                                   Rickshaw Theatre
# 509                            Christ Church Cathedral
# 510                                       Rogers Arena
# 511                         Trinity Western University
# 512                                      Vogue Theatre
# 513                                 Commodore Ballroom
# 514                                       The Imperial
# 515                                   Biltmore Cabaret
#
# [516 rows x 7 columns]

# %% [markdown]
# # Event Categories
# Categories or tags used to group events together on similarity. Here each event can have multiple tags.
#
# ## Places around the web
# Looking at the different examples from around the web we find:
#
# ### [Facebook](https://www.facebook.com/events/)
# Doesn't specify event type
#
# ### [Eventbrite](https://www.eventbrite.ca/d/canada--vancouver/events/)
# Has the following categories: Arts, Business, Charity & Causes, Community, Film & Media, Food & Drink and Music. Here each category has sub-categories:
# * Arts: Fine Art, Comedy, Painting, Theatre, Other, Musical, Dance, ...
# * Business: Startups, Career, Educators, Other, Sales & Marketing, Investment, Environment & Sustainability, ...
# * Charity & Causes: Other, Education, Human Rights, Poverty, Environment and Healthcare
# * Community: Heritage, Other, LGBT, City & Town and Historic
# * Film & Media: Film, Other, TV, Adult and Comedy
# * Food & Drink: Spirits, Wine, Other and Food
# * Music: Electronic & EDM, Classical, Other, Folk, Hip Hop & Rap, Indie, Spiritual & Religious, Opera, ...
#
# ### [Tourism Vancouver](https://www.tourismvancouver.com/)
# Has a all of different sometimes arcane categories (which makes it harder to use). Here we have a few of them: Aboriginal, Comedy, Concerts/Clubs, Conventions and Consumer Shows, Culinary, Dance, Dine Out Vancouver Festival, Family Friendly, Film/Video/Media, Literary, Multicultural, Museum/Gallery/History, LGBTQ2, Theatre, Visual Arts ...
#
# ### [Ticketmaster](https://www.ticketmaster.ca/)
# Has the following categories: music, sports, arts & theatre, family and miscellaneous. Here each category has sub-categories:
# * Music: Rock and Pop, Country and Folk, Rap and Hip-Hop, Jazz and Blues, World Music, Latin, New Age and Spiritual, Comedy, ...
# * Sports: Basketball, Football, Hockey, Baseball, Soccer, Motosports, Wrestling, Rodeo, Golf, Tennis, Boxing, ...
# * Arts & Theatre: Ballet and Dance, Opera, Museums and Exhibits, Broadway, Off-Broadway, Plays, Comedy, Classical, ...
# * Family: Family Attractions, Ice Shows, Circus, Fairs and Festivals, Magic Shows, ...
#
# ## Suggestions
# Looking at the examples from above we could just use tags to describe our events. Based on the tags we can then group our events. Events with the tag: Fine Arts, Comedy, Painting, Theatre, Musical or Dance can then be grouped as Arts. This also means that we don't have to keep track of the category in our data set. We just need to specify which tags make up a category. So instead of trying to come up with the category, we just need to come up with the number of tags that match with the given features (detail, name, venue, time, ...)

# %%
# This is our current category list
cats = set([item for i in events['source-tags'].tolist() if type(i) == list for item in i])
cats
# Out:
# {'Activism',
#  'Attractions',
#  'Comedy',
#  'Concerts',
#  'Dance',
#  'Festivals',
#  'Film',
#  'Food & Drink',
#  'Forums & Talks',
#  'Fundraisers & Charity',
#  'Galleries',
#  'Holiday',
#  "Kids' Stuff",
#  'Literary/Books',
#  'Markets',
#  'Museums',
#  'Nightlife',
#  'Other',
#  'Performing Arts',
#  'Sports',
#  'Theatre'}

# %%
# Out:
# 'ddeeff'
